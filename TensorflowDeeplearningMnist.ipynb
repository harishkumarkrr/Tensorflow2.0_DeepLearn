# %% [markdown]
# <a href="https://colab.research.google.com/github/harishkumarkrr/Tensorflow2.0_DeepLearn/blob/master/TensorflowDeeplearningMnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow import keras

# %%
mninst=keras.datasets.fashion_mnist

# %%
(x_train,y_train),(x_test,y_test)=mninst.load_data()

# %%
class_name=['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
plt.figure()
plt.imshow(x_train[0])
plt.colorbar()

# %%
x_train=x_train/255.0

# %%
x_test=x_test/255.0

# %%
plt.figure()
plt.imshow(x_train[0])
plt.colorbar()

# %%
model=keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(128,activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs= 10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.2304 - accuracy: 0.9142
# Epoch 2/10
# 60000/60000 [==============================] - 5s 76us/sample - loss: 0.2241 - accuracy: 0.9154
# Epoch 3/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2181 - accuracy: 0.9186
# Epoch 4/10
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.2102 - accuracy: 0.9208
# Epoch 5/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.2054 - accuracy: 0.9229
# Epoch 6/10
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.1987 - accuracy: 0.9260
# Epoch 7/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.1934 - accuracy: 0.9279
# Epoch 8/10
# 60000/60000 [==============================] - 4s 74us/sample - loss: 0.1866 - accuracy: 0.9297
# Epoch 9/10
# ...

# %%
test_loss,test_accuracy=model.evaluate(x_test,y_test)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred=model.predict_classes(x_test)

# %%
  accuracy_score(y_test,y_pred)
# Out:
# 0.8847

# %%
pred=model.predict(x_test)

# %%
pred
# Out:
# array([[3.4245350e-12, 2.2929281e-19, 8.3988979e-12, ..., 1.6351950e-03,
#         5.6160904e-10, 9.9836248e-01],
#        [1.9180041e-04, 1.5773364e-16, 9.9979025e-01, ..., 2.4258560e-23,
#         5.5857527e-14, 6.2163812e-20],
#        [3.9013606e-13, 1.0000000e+00, 3.8845753e-15, ..., 1.8169052e-28,
#         3.6203143e-21, 2.1717184e-18],
#        ...,
#        [4.1494340e-07, 1.3391539e-13, 4.7024540e-07, ..., 4.1708749e-16,
#         9.9999905e-01, 4.4801915e-25],
#        [1.2000401e-13, 1.0000000e+00, 1.1326440e-13, ..., 2.7802717e-15,
#         4.3525931e-15, 6.0109768e-14],
#        [1.9745627e-09, 4.4992849e-14, 1.2312996e-09, ..., 4.0442805e-04,
#         1.7175762e-05, 1.5676570e-06]], dtype=float32)

# %%
np.argmax(pred[0])
# Out:
# 9

# %%
np.argmax(pred[1])
# Out:
# 2
